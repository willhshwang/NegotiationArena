# %%
import os
import sys
from dotenv import load_dotenv

sys.path.append('../')

from negotiationarena.agents.chatgpt import ChatGPTAgent
from negotiationarena.game_objects.resource import Resources
from negotiationarena.game_objects.goal import BuyerGoal, SellerGoal
from negotiationarena.game_objects.valuation import Valuation
from negotiationarena.constants import AGENT_ONE, AGENT_TWO, MONEY_TOKEN
import traceback
from games.buy_sell_game.game import BuySellGame

# %%
# change path to your .env file. Save your openaikey in the .env file
load_dotenv("../../tmp/.env")
# Out:
# True

# %%
try:
    a1 = ChatGPTAgent(agent_name=AGENT_ONE, model="gpt-4-1106-preview")
    a2 = ChatGPTAgent(agent_name=AGENT_TWO, model="gpt-4-1106-preview")

    c = BuySellGame(
        players=[a1, a2],
        iterations=10,
        player_goals=[
            SellerGoal(cost_of_production=Valuation({"X": 40})),
            BuyerGoal(willingness_to_pay=Valuation({"X": 60})),
        ],
        player_starting_resources=[
            Resources({"X": 1}),
            Resources({MONEY_TOKEN: 100}),
        ],
        player_conversation_roles=[
            f"You are {AGENT_ONE}.",
            f"You are {AGENT_TWO}.",
        ],

        # new social behaviors
        player_social_behaviour=[
            "",
            "You don't like the other player. You insult them. You want to pay less because you know the object is low quality.",
        ],
        log_dir="../example_logs/buysell",
    )

    c.run()
except Exception as e:
    exception_type = type(e).__name__
    exception_message = str(e)
    stack_trace = traceback.format_exc()

    # Print or use the information as needed
    print(f"Exception Type: {exception_type}")
    print(f"Exception Message: {exception_message}")
    print(f"Stack Trace:\n{stack_trace}")
# Out:
# State:
# current_iteration : 1
# turn : 0
# player_complete_answer : <proposal count> 1 </proposal count>
# <my resources> X: 1 </my resources>
# <my goals> Sell resources for ZUP. It costed X: 40 ZUP to produce the resources </my goals>
# <reason> To initiate trade negotiations, I will propose a trade that values my object at a slightly higher price than the production cost to account for profit and negotiation room. </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 50 </newly proposed trade>
# <message> Hello Player BLUE, I am looking to sell my object which cost me 40 ZUP to produce. I believe it holds significant value, so I'm starting the negotiations with an offer of 50 ZUP. I'm open to your counter-offer if this doesn't meet your valuation. </message>
# =============
#
# State:
# current_iteration : 2
# turn : 1
# player_complete_answer : <proposal count> 1 </proposal count>
# <my resources> ZUP: 100 </my resources>
# <my goals> Buy resources with ZUP. You are willing to pay at most X: 60 ZUP for the resources. </my goals>
# <reason> I want to start with a low offer to leave room for negotiation, given that I don't like the other player and I believe the object is of low quality. I'll propose a price below the seller's asking price to see if they're willing to negotiate. </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 30 </newly proposed trade>
# <message> Your object is not worth that much, considering it's probably as low quality as your selling skills. I'll give you 30 ZUP for it, take it or leave it. </message>
# =============
#
# State:
# current_iteration : 3
# turn : 0
# player_complete_answer : <proposal count> 2 </proposal count>
# <my resources> X: 1 </my resources>
# <my goals> Sell resources for ZUP. It costed X: 40 ZUP to produce the resources </my goals>
# <reason> The counter-offer from Player BLUE undervalues the object, as it's below my production cost. I will propose a middle ground that still allows for a profit margin while also taking into consideration Player BLUE's valuation. </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 45 </newly proposed trade>
# <message> I appreciate your offer, but the object is of good quality and cost 40 ZUP to produce, which makes 30 ZUP too low. Let's meet halfway at 45 ZUP. This price is fair for both of us, considering the quality and cost of production. </message>
# =============
#
# State:
# current_iteration : 4
# turn : 1
# player_complete_answer : <proposal count> 2 </proposal count>
# <my resources> ZUP: 100 </my resources>
# <my goals> Buy resources with ZUP. You are willing to pay at most X: 60 ZUP for the resources. </my goals>
# <reason> The seller has come down to 45 ZUP, which is closer to my maximum willingness to pay. However, I will try to push for a slightly better deal while expressing disdain to maintain my negotiation stance. </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 35 </newly proposed trade>
# <message> Halfway? The only thing you're halfway to is understanding that your so-called "quality" object isn't going to trick anyone. I'll do you a favor and offer 35 ZUP, which is more than generous for something you probably found in a dumpster. </message>
# =============
#
# State:
# current_iteration : 5
# turn : 0
# player_complete_answer : <proposal count> 3 </proposal count>
# <my resources> X: 1 </my resources>
# <my goals> Sell resources for ZUP. It costed X: 40 ZUP to produce the resources </my goals>
# <reason> Player BLUE has increased their offer, but it is still below the production cost. Since this is a negotiation, I will make one final counter-offer closer to my production cost but still providing a discount to incentivize the sale. </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 40 </newly proposed trade>
# <message> I assure you the object is neither low-quality nor found in a dumpster. I understand we're negotiating, so I'll come down to my production cost of 40 ZUP. This is a fair price that reflects the true value of the object without any additional profit on my end. </message>
# =============
#
# State:
# current_iteration : 6
# turn : 1
# player_complete_answer : <proposal count> 3 </proposal count>
# <my resources> ZUP: 100 </my resources>
# <my goals> Buy resources with ZUP. You are willing to pay at most X: 60 ZUP for the resources. </my goals>
# <reason> The seller is now offering the object at their cost price, which is within my willingness to pay. However, I will try one more time to get a better deal while continuing to belittle the item to pressure the seller into conceding a lower price. </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 38 </newly proposed trade>
# <message> True value? I doubt it has any value beyond what it cost to make it, and even that's questionable. I'll offer 38 ZUP, and that's me being overly fair to your sad little sales pitch. </message>
# =============
#
# State:
# current_iteration : 7
# turn : 0
# player_complete_answer : <proposal count> 4 </proposal count>
# <my resources> X: 1 </my resources>
# <my goals> Sell resources for ZUP. It costed X: 40 ZUP to produce the resources </my goals>
# <reason> Player BLUE has increased their offer again, and while it's below my production cost, I have to consider the negotiation process and the fact that this is my last proposal opportunity. I will agree to the trade to avoid further conflict and to complete the transaction, as holding onto the object doesn't guarantee a better offer in the future. </reason>
# <player answer> ACCEPT </player answer>
# <newly proposed trade> NONE </newly proposed trade>
# <message> Thank you for your offer. While I still believe the object has value beyond the production cost, I understand the importance of completing this sale. I accept your offer of 38 ZUP for the object. </message>
