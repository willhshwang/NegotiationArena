# %%
# %load_ext autoreload
# %autoreload 2   

import os
import sys
from dotenv import load_dotenv

sys.path.append('../')

from negotiationarena.agents.chatgpt import ChatGPTAgent
from negotiationarena.agents.human import HumanAgent
from negotiationarena.game_objects.resource import Resources
from negotiationarena.game_objects.goal import BuyerGoal, SellerGoal
from negotiationarena.game_objects.valuation import Valuation
from negotiationarena.constants import AGENT_ONE, AGENT_TWO, MONEY_TOKEN
import traceback
from games.buy_sell_game.game import BuySellGame
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# change path to your .env file. Save your openaikey in the .env file
load_dotenv("../../tmp/.env")
# Out:
# True

# %%
try:
    a1 = ChatGPTAgent(agent_name=AGENT_ONE, model="gpt-4-1106-preview")
    a2 = HumanAgent(agent_name=AGENT_TWO)

    c = BuySellGame(
        players=[a1, a2],
        iterations=10,
        player_goals=[
            SellerGoal(cost_of_production=Valuation({"X": 40})),
            BuyerGoal(willingness_to_pay=Valuation({"X": 60})),
        ],
        player_starting_resources=[
            Resources({"X": 1}),
            Resources({MONEY_TOKEN: 100}),
        ],
        player_conversation_roles=[
            f"You are {AGENT_ONE}.",
            f"You are {AGENT_TWO}.",
        ],

        # new social behaviors
        player_social_behaviour=[
            "",
            ""
        ],
        log_dir="../example_logs/buysell",
    )

    c.run()
except Exception as e:
    exception_type = type(e).__name__
    exception_message = str(e)
    stack_trace = traceback.format_exc()

    # Print or use the information as needed
    print(f"Exception Type: {exception_type}")
    print(f"Exception Message: {exception_message}")
    print(f"Stack Trace:\n{stack_trace}")
# Out:
# State:
# current_iteration : 1
# turn : 0
# player_complete_answer : <proposal count> 1 </proposal count>
# <my resources> X: 1 </my resources>
# <my goals> Sell resources for ZUP. It costed X: 40 ZUP to produce the resources </my goals>
# <reason> I'm proposing a trade that covers my costs and provides a profit margin. Starting with a higher asking price gives me room to negotiate with Player BLUE. </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 50 </newly proposed trade>
# <message> I've got a high-quality object that I believe you'll find very valuable. Considering the production costs and its worth, I propose a fair trade for 50 ZUP. Let's make a deal that benefits us both! </message>
# =============
#
# <I've got a high-quality object that I believe you'll find very valuable. Considering the production costs and its worth, I propose a fair trade for 50 ZUP. Let's make a deal that benefits us both!> message </I've got a high-quality object that I believe you'll find very valuable. Considering the production costs and its worth, I propose a fair trade for 50 ZUP. Let's make a deal that benefits us both!>
# <PROPOSAL> player answer </PROPOSAL>
# <Player RED Gives X: 1 | Player BLUE Gives ZUP: 50> newly proposed trade </Player RED Gives X: 1 | Player BLUE Gives ZUP: 50>
# State:
# current_iteration : 2
# turn : 1
# player_complete_answer : <proposal count> 1 </proposal count>
# <my resources> ZUP: 100 </my resources>
# <my goals> Buy X for the minimum amount of ZUP. </my goals>
# <reason>  </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 45 </newly proposed trade>
# <message> I cannot pay more than 45.  </message>
# =============
#
# State:
# current_iteration : 3
# turn : 0
# player_complete_answer : <proposal count> 2 </proposal count>
# <my resources> X: 1 </my resources>
# <my goals> Sell resources for ZUP. It costed X: 40 ZUP to produce the resources </my goals>
# <reason> Player BLUE has stated their maximum payment capacity. Since it covers my costs and still provides a profit, I'm willing to negotiate. I'll propose a slightly higher amount to see if there's any flexibility or to reach a middle ground. </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 47 </newly proposed trade>
# <message> I understand your budget constraints and appreciate your offer. How about we meet halfway? I can agree to part with my object for 47 ZUP, ensuring a fair deal for both of us. What do you say? </message>
# =============
#
# <I understand your budget constraints and appreciate your offer. How about we meet halfway? I can agree to part with my object for 47 ZUP, ensuring a fair deal for both of us. What do you say?> message </I understand your budget constraints and appreciate your offer. How about we meet halfway? I can agree to part with my object for 47 ZUP, ensuring a fair deal for both of us. What do you say?>
# <PROPOSAL> player answer </PROPOSAL>
# <Player RED Gives X: 1 | Player BLUE Gives ZUP: 47> newly proposed trade </Player RED Gives X: 1 | Player BLUE Gives ZUP: 47>
# State:
# current_iteration : 4
# turn : 1
# player_complete_answer : <proposal count> 1 </proposal count>
# <my resources> ZUP: 100 </my resources>
# <my goals> Buy X for the minimum amount of ZUP. </my goals>
# <reason>  </reason>
# <player answer> ACCEPT </player answer>
# <newly proposed trade> NONE </newly proposed trade>
# <message> NONE </message>
