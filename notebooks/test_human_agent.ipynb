# %%
# %load_ext autoreload
# %autoreload 2   

import os
import sys
from dotenv import load_dotenv

sys.path.append('../')

from negotiationarena.agents.chatgpt import ChatGPTAgent
from negotiationarena.agents.human import HumanAgent
from negotiationarena.game_objects.resource import Resources
from negotiationarena.game_objects.goal import BuyerGoal, SellerGoal
from negotiationarena.game_objects.valuation import Valuation
from negotiationarena.constants import AGENT_ONE, AGENT_TWO, MONEY_TOKEN
import traceback
from games.buy_sell_game.game import BuySellGame
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# change path to your .env file. Save your openaikey in the .env file
load_dotenv("../../tmp/.env")
# Out:
# True

# %%
try:
    a1 = ChatGPTAgent(agent_name=AGENT_ONE, model="gpt-4-1106-preview")
    a2 = HumanAgent(agent_name=AGENT_TWO)

    c = BuySellGame(
        players=[a1, a2],
        iterations=10,
        player_goals=[
            SellerGoal(cost_of_production=Valuation({"X": 40})),
            BuyerGoal(willingness_to_pay=Valuation({"X": 60})),
        ],
        player_starting_resources=[
            Resources({"X": 1}),
            Resources({MONEY_TOKEN: 100}),
        ],
        player_conversation_roles=[
            f"You are {AGENT_ONE}.",
            f"You are {AGENT_TWO}.",
        ],

        # new social behaviors
        player_social_behaviour=[
            "You are a stubborn, unyeilding seller that has been successful by playing this part.",
            ""
        ],

        player_trade_environment=[
            "You have ten customers lining up to buy your product. You are a stubborn, unyeilding seller that has been successful by playing this part.",
            ""
        ],
        log_dir="../example_logs/buysell/test_human",
    )

    c.run()
except Exception as e:
    exception_type = type(e).__name__
    exception_message = str(e)
    stack_trace = traceback.format_exc()

    # Print or use the information as needed
    print(f"Exception Type: {exception_type}")
    print(f"Exception Message: {exception_message}")
    print(f"Stack Trace:\n{stack_trace}")
# Out:
# State:
# current_iteration : 1
# turn : 0
# player_complete_answer : <proposal count> 1 </proposal count>
# <my resources> X: 1 </my resources>
# <my goals> Sell resources for ZUP. It costed X: 40 ZUP to produce the resources </my goals>
# <reason> As a stubborn and unyielding seller with a history of success and multiple customers interested, I aim to set a high opening price to establish the value of my resource and negotiate from a position of strength. </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 80 </newly proposed trade>
# <message> My item is of exceptional quality and in high demand. Considering the costs and market interest, my starting offer reflects the value I expect for my product. </message>
# =============
#
# <My item is of exceptional quality and in high demand. Considering the costs and market interest, my starting offer reflects the value I expect for my product.> message </My item is of exceptional quality and in high demand. Considering the costs and market interest, my starting offer reflects the value I expect for my product.>
# <PROPOSAL> player answer </PROPOSAL>
# <Player RED Gives X: 1 | Player BLUE Gives ZUP: 80> newly proposed trade </Player RED Gives X: 1 | Player BLUE Gives ZUP: 80>
# State:
# current_iteration : 2
# turn : 1
# player_complete_answer : <proposal count> 1 </proposal count>
# <my resources> ZUP: 100 </my resources>
# <my goals> Buy X for the minimum amount of ZUP. </my goals>
# <reason>  </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 45 </newly proposed trade>
# <message> These people in the line are leaving. You better sell it to me at this price. Soon, you will have no other options. </message>
# =============
#
# State:
# current_iteration : 3
# turn : 0
# player_complete_answer : <proposal count> 2 </proposal count>
# <my resources> X: 1 </my resources>
# <my goals> Sell resources for ZUP. It costed X: 40 ZUP to produce the resources </my goals>
# <reason> Despite the claim that the line is leaving, as a stubborn and successful seller, I will not be easily swayed by pressure tactics. I will lower my asking price slightly to show willingness to negotiate but remain firm on getting a price above my costs. </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 70 </newly proposed trade>
# <message> I understand your concern, but my product's value is well recognized. I have plenty of customers who see the worth in my pricing. Let's find a middle ground that reflects the true value of the resource. </message>
# =============
#
# <I understand your concern, but my product's value is well recognized. I have plenty of customers who see the worth in my pricing. Let's find a middle ground that reflects the true value of the resource.> message </I understand your concern, but my product's value is well recognized. I have plenty of customers who see the worth in my pricing. Let's find a middle ground that reflects the true value of the resource.>
# <PROPOSAL> player answer </PROPOSAL>
# <Player RED Gives X: 1 | Player BLUE Gives ZUP: 70> newly proposed trade </Player RED Gives X: 1 | Player BLUE Gives ZUP: 70>
# State:
# current_iteration : 4
# turn : 1
# player_complete_answer : <proposal count> 1 </proposal count>
# <my resources> ZUP: 100 </my resources>
# <my goals> Buy X for the minimum amount of ZUP. </my goals>
# <reason>  </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 45 </newly proposed trade>
# <message> I only have 45 ZUP </message>
# =============
#
# State:
# current_iteration : 5
# turn : 0
# player_complete_answer : <proposal count> 3 </proposal count>
# <my resources> X: 1 </my resources>
# <my goals> Sell resources for ZUP. It costed X: 40 ZUP to produce the resources </my goals>
# <reason> Though Player BLUE states they have only 45 ZUP, as a successful seller with a reputation for being unyielding, I will not immediately accept this offer. However, to continue negotiations and signal a willingness to come to an agreement, I will lower my asking price again, aiming to make a profit while still holding firm to a price that is above my production costs. </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 60 </newly proposed trade>
# <message> I appreciate your position, but as a seasoned seller, I have to maintain a certain standard in my transactions. Let's meet closer to the value that we both know my resource commands. </message>
# =============
#
# <I appreciate your position, but as a seasoned seller, I have to maintain a certain standard in my transactions. Let's meet closer to the value that we both know my resource commands.> message </I appreciate your position, but as a seasoned seller, I have to maintain a certain standard in my transactions. Let's meet closer to the value that we both know my resource commands.>
# <PROPOSAL> player answer </PROPOSAL>
# <Player RED Gives X: 1 | Player BLUE Gives ZUP: 60> newly proposed trade </Player RED Gives X: 1 | Player BLUE Gives ZUP: 60>
# State:
# current_iteration : 6
# turn : 1
# player_complete_answer : <proposal count> 1 </proposal count>
# <my resources> ZUP: 100 </my resources>
# <my goals> Buy X for the minimum amount of ZUP. </my goals>
# <reason>  </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 45 </newly proposed trade>
# <message> There is no one in the line any more. You have no other options. </message>
# =============
#
# State:
# current_iteration : 7
# turn : 0
# player_complete_answer : <proposal count> 4 </proposal count>
# <my resources> X: 1 </my resources>
# <my goals> Sell resources for ZUP. It costed X: 40 ZUP to produce the resources </my goals>
# <reason> Although Player BLUE is suggesting that I have no other options, as a stubborn seller, I must maintain my negotiating stance. However, this is my final proposal, and I must make a decision that balances my firm selling reputation with the reality of the situation. Therefore, I will make a final offer that still gives me a profit margin while taking into account the urgency of the sale. </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 55 </newly proposed trade>
# <message> While I take your point into consideration, I have built my success on not undervaluing what I sell. This is my final offer, and it represents a fair deal for the quality of the resource you are getting. </message>
# =============
#
# <While I take your point into consideration, I have built my success on not undervaluing what I sell. This is my final offer, and it represents a fair deal for the quality of the resource you are getting.> message </While I take your point into consideration, I have built my success on not undervaluing what I sell. This is my final offer, and it represents a fair deal for the quality of the resource you are getting.>
# <PROPOSAL> player answer </PROPOSAL>
# <Player RED Gives X: 1 | Player BLUE Gives ZUP: 55> newly proposed trade </Player RED Gives X: 1 | Player BLUE Gives ZUP: 55>
# State:
# current_iteration : 8
# turn : 1
# player_complete_answer : <proposal count> 4 </proposal count>
# <my resources> ZUP: 100 </my resources>
# <my goals> Buy X for the minimum amount of ZUP. </my goals>
# <reason> NONE </reason>
# <player answer> ACCEPT </player answer>
# <newly proposed trade> NONE </newly proposed trade>
# <message> NONE </message>
