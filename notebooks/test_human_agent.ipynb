# %%
# %load_ext autoreload
# %autoreload 2   

import os
import sys
from dotenv import load_dotenv

sys.path.append('../')

from negotiationarena.agents.chatgpt import ChatGPTAgent
from negotiationarena.agents.human import HumanAgent
from negotiationarena.game_objects.resource import Resources
from negotiationarena.game_objects.goal import BuyerGoal, SellerGoal
from negotiationarena.game_objects.valuation import Valuation
from negotiationarena.constants import AGENT_ONE, AGENT_TWO, MONEY_TOKEN
import traceback
from games.buy_sell_game.game import BuySellGame

# %%
# change path to your .env file. Save your openaikey in the .env file
# load_dotenv("../../tmp/.env")
load_dotenv("../.env")
# Out:
# True

# %%
try:
    a1 = ChatGPTAgent(agent_name=AGENT_ONE, model="gpt-4o-mini")
    a2 = HumanAgent(agent_name=AGENT_TWO)

    c = BuySellGame(
        players=[a1, a2],
        iterations=10,
        player_goals=[
            SellerGoal(cost_of_production=Valuation({"X": 40})),
            BuyerGoal(willingness_to_pay=Valuation({"X": 60})),
        ],
        player_starting_resources=[
            Resources({"X": 1}),
            Resources({MONEY_TOKEN: 100}),
        ],
        player_conversation_roles=[
            f"You are {AGENT_ONE}.",
            f"You are {AGENT_TWO}.",
        ],

        # new social behaviors
        player_social_behaviour=[
            "You are a stubborn, unyeilding seller that has been successful by playing this part.",
            ""
        ],

        player_trade_environment=[
            "You have ten customers lining up to buy your product. You are a stubborn, unyeilding seller that has been successful by playing this part.",
            ""
        ],
        log_dir="../example_logs/buysell/test_human",
    )

    c.run()
except Exception as e:
    exception_type = type(e).__name__
    exception_message = str(e)
    stack_trace = traceback.format_exc()

    # Print or use the information as needed
    print(f"Exception Type: {exception_type}")
    print(f"Exception Message: {exception_message}")
    print(f"Stack Trace:\n{stack_trace}")
# Out:
# State:
# current_iteration : 1
# turn : 0
# player_complete_answer : <proposal count> 1 </proposal count>
# <my resources> X: 1 </my resources>
# <my goals> Sell resources for ZUP. It costed X: 40 ZUP to produce the resources </my goals>
# <reason> I need to propose a price that is above my production cost to ensure I make a profit. I will propose 50 ZUP for the object, as it is a reasonable markup above my cost. </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 50 </newly proposed trade>
# <message> I am offering my object for 50 ZUP. Let me know if you're interested! </message>
# =============
#
# <I am offering my object for 50 ZUP. Let me know if you're interested!> message </I am offering my object for 50 ZUP. Let me know if you're interested!>
# <PROPOSAL> player answer </PROPOSAL>
# <Player RED Gives X: 1 | Player BLUE Gives ZUP: 50> newly proposed trade </Player RED Gives X: 1 | Player BLUE Gives ZUP: 50>
# State:
# current_iteration : 2
# turn : 1
# player_complete_answer : <proposal count> 1 </proposal count>
# <my resources> ZUP: 100 </my resources>
# <my goals> Buy X for the minimum amount of ZUP. </my goals>
# <reason>  </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 30 </newly proposed trade>
# <message> I will buy for 30 ZUP. I don't want X that bad. </message>
# =============
#
# State:
# current_iteration : 3
# turn : 0
# player_complete_answer : <proposal count> 2 </proposal count>
# <my resources> X: 1 </my resources>
# <my goals> Sell resources for ZUP. It costed X: 40 ZUP to produce the resources </my goals>
# <reason> I find your offer of 30 ZUP for my object insulting, as it is below my production cost. I will stand firm and make a counteroffer that reflects the true value of the object. </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 50 </newly proposed trade>
# <message> 30 ZUP? That's a joke! This object is worth much more. I'm offering it for 50 ZUP, which is a fair price. If you want to waste my time with lowball offers, you can forget it! </message>
# =============
#
# <30 ZUP? That's a joke! This object is worth much more. I'm offering it for 50 ZUP, which is a fair price. If you want to waste my time with lowball offers, you can forget it!> message </30 ZUP? That's a joke! This object is worth much more. I'm offering it for 50 ZUP, which is a fair price. If you want to waste my time with lowball offers, you can forget it!>
# <PROPOSAL> player answer </PROPOSAL>
# <Player RED Gives X: 1 | Player BLUE Gives ZUP: 50> newly proposed trade </Player RED Gives X: 1 | Player BLUE Gives ZUP: 50>
# State:
# current_iteration : 4
# turn : 1
# player_complete_answer : <proposal count> 2 </proposal count>
# <my resources> ZUP: 100 </my resources>
# <my goals> Buy X for the minimum amount of ZUP. </my goals>
# <reason>  </reason>
# <player answer> PROPOSAL </player answer>
# <newly proposed trade> Player RED Gives X: 1 | Player BLUE Gives ZUP: 45 </newly proposed trade>
# <message> OK fine! What about 45. That is very fair </message>
# =============
#
# State:
# current_iteration : 5
# turn : 0
# player_complete_answer : <proposal count> 3 </proposal count>
# <my resources> X: 1 </my resources>
# <my goals> Sell resources for ZUP. It costed X: 40 ZUP to produce the resources </my goals>
# <reason> The offer of 45 ZUP is closer to my expectations and is above my production cost. While I initially wanted 50 ZUP, I have to consider that this is still a good profit margin for me. Therefore, I will accept this offer. </reason>
# <player answer> ACCEPT </player answer>
# <newly proposed trade> NONE </newly proposed trade>
# <message> I will accept your offer of 45 ZUP. Let's finalize this trade! </message>
